# %% [markdown]
# <a href="https://colab.research.google.com/github/majid55321/Physics-MCQS-App/blob/main/Physics_MCQS_App.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries
# !pip install streamlit -q
# !pip install pyngrok -q
# !ngrok authtoken 2nmnJ8ttQOh4DjvY0LRM5quCnsC_3YkgTY7WAQKCscivVLoRP


import streamlit as st
from pyngrok import ngrok

# Important Physics MCQs data
physics_mcqs = [
    {
        "question": "What is the SI unit of force?",
        "choices": ["Joule", "Newton", "Pascal", "Watt"],
        "answer": "Newton"
    },
    {
        "question": "Who proposed the law of universal gravitation?",
        "choices": ["Albert Einstein", "Isaac Newton", "Galileo Galilei", "James Clerk Maxwell"],
        "answer": "Isaac Newton"
    },
    {
        "question": "What is the speed of light in vacuum?",
        "choices": ["3 × 10^8 m/s", "3 × 10^6 m/s", "3 × 10^4 m/s", "3 × 10^2 m/s"],
        "answer": "3 × 10^8 m/s"
    },
    {
        "question": "Which law explains the relation between current and potential difference?",
        "choices": ["Faraday's Law", "Ohm's Law", "Hooke's Law", "Ampere's Law"],
        "answer": "Ohm's Law"
    },
    {
        "question": "Which particle has a negative charge?",
        "choices": ["Proton", "Neutron", "Electron", "Positron"],
        "answer": "Electron"
    }
]

# Function to display MCQs and provide solutions
def display_mcqs():
    score = 0
    for i, mcq in enumerate(physics_mcqs):
        st.write(f"Q{i+1}: {mcq['question']}")
        answer = st.radio("Choose your answer:", mcq["choices"], key=i)
        if st.button(f"Submit Answer {i+1}"):
            if answer == mcq['answer']:
                st.success("Correct!")
                score += 1
            else:
                st.error(f"Incorrect. The correct answer is {mcq['answer']}")
        st.write("---")

    if st.button("Show Final Score"):
        st.write(f"Your Score: {score}/{len(physics_mcqs)}")

# Streamlit App
st.title("Important Physics MCQs")
st.write("Test your Physics knowledge with these important MCQs and solutions!")

display_mcqs()

# Launch ngrok to make app accessible externally
public_url = ngrok.connect(8501, "http")  # Specify the port and protocol
st.write(f"App is live at {public_url}")
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# 2024-10-22 09:03:20.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.954 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.970 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.985 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.990 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:20.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.003 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.010 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.013 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.014 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.051 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.076 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.077 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.079 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.081 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.088 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.091 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.093 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.099 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.111 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-22 09:03:21.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
